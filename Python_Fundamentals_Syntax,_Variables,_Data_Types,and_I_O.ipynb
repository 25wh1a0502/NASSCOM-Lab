# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a0502/NASSCOM-Lab/blob/main/Python_Fundamentals_Syntax%2C_Variables%2C_Data_Types%2Cand_I_O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
if True:
  print("it is indented correctly")
else:
  print("won't run")
# Out:
# Hello World!
# it is indented correctly

# %%
name="Neda"
age=19
height=5.1
print("Name:",name)
print("Age:",age)
print("Height:",height)
name="Amodini"
print("New value of name:",name)
# Out:
# Name: Neda
# Age: 19
# Height: 5.1
# New value of name: Amodini

# %%
a=2
print(type(a))
b=2.18
print(type(b))
# Out:
# <class 'int'>
# <class 'float'>

# %%
c="Python"
print(type(c))
d=True
print(type(d))
# Out:
# <class 'str'>
# <class 'bool'>

# %%
e=[1,2,"three"]
print(type(e),e)
f={"Name":"Neda","Age":19}
print(type(f),f)
# Out:
# <class 'list'> [1, 2, 'three']
# <class 'dict'> {'Name': 'Neda', 'Age': 19}

# %%
print("Welcome to python!")
# Out:
# Welcome to python!

# %%
name=input("Enter the name:")
print("Hello",name)
# Out:
# Enter the name:NEDA
# Hello NEDA

# %%
age=int(input("Enter your age:"))
print("You will be",age+1,"next year!")
# Out:
# Enter your age:19
# You will be 20 next year!
